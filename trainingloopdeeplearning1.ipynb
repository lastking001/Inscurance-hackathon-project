# %% [markdown]
# <a href="https://colab.research.google.com/github/lastking001/Inscurance-hackathon-project/blob/main/trainingloopdeeplearning1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
print(torch.__version__)
# Out:
# 2.9.0+cpu

# %%
import torch

# data
x = torch.tensor([1.0, 2.0, 3.0, 4.0])
y_true = torch.tensor([2.0, 4.0, 6.0, 8.0])

# parameter
w = torch.tensor(0.0, requires_grad=True)

learning_rate = 0.01

for epoch in range(100):

    # forward pass
    y_pred = w * x

    # loss
    loss = ((y_pred - y_true) ** 2).mean()

    # backward pass
    loss.backward()

    # update
    with torch.no_grad():
        w -= learning_rate * w.grad

    # reset gradient
    w.grad.zero_()

    if epoch % 10 == 0:
        print(f"Epoch {epoch}: loss={loss.item():.4f}, w={w.item():.4f}")
# Out:
# Epoch 0: loss=30.0000, w=0.3000
# Epoch 10: loss=1.1628, w=1.6653
# Epoch 20: loss=0.0451, w=1.9341
# Epoch 30: loss=0.0017, w=1.9870
# Epoch 40: loss=0.0001, w=1.9974
# Epoch 50: loss=0.0000, w=1.9995
# Epoch 60: loss=0.0000, w=1.9999
# Epoch 70: loss=0.0000, w=2.0000
# Epoch 80: loss=0.0000, w=2.0000
# Epoch 90: loss=0.0000, w=2.0000
